# %%
m = float(input('Введите  μ:'))
p = float(input('Введите  ρ:'))
q = 1
P = (1 - p)* 100
print(f'Доля времени бездействия (P) = {P}%')
L = p/(P)
print(f'Среднее число автомобилей, находящихся в системе: {L}')
W = L/(m*(P))
print(f'Средняя продолжительность пребывания клиента в системе: {W}')
Lq = p**2/P
print(f'Среднее число автомобилей в очереди на обслуживание: {Lq}')
Wq = p/(m*P)
print(f'Средняя продолжительность пребывания автомобиля в очереди: {Wq}')
A = m*P*q
print(f'Абсолютная пропускная способность: {A}')
freq = m*P
# Out:
# Введите  μ:0.952
# Введите  ρ:0.893
# Доля времени бездействия (P) = 10.7%
# Среднее число автомобилей, находящихся в системе: 0.08345794392523365
# Средняя продолжительность пребывания клиента в системе: 0.008193075465840105
# Среднее число автомобилей в очереди на обслуживание: 0.07452794392523365
# Средняя продолжительность пребывания автомобиля в очереди: 0.08766590748448913
# Абсолютная пропускная способность: 10.186399999999999

# %%
# n = int(input('Введите кол-во заявок:'))
alpha = int(input("Сколько людей подошло в кофейню в среднем за 600 сек(10 мин):"))
t = float(input("Средняя продолжительнсоть обслуживания: "))
m = 1/t
print(f"Интенсивность потока:{m}")
p = alpha/m
print(f"Коэфф загрузки системы: {p}")
q = (m /(alpha+m))*100
print(f"Относиельная пропускная способность : {q}")
A = alpha*q
print(f"Абсолютная пропуск способность: {A}")
P = (1-q)
print(f"Вероятность отказа: {P}")
# Out:
# Сколько людей подошло в кофейню в среднем за 10 мин:6
# Средняя продолжительнсоть обслуживания43.3
# Интенсивность потока:0.023094688221709007
# Коэфф загрузки системы: 259.8
# Относиельная пропускная способность : 0.3834355828220859
# Абсолютная пропуск способность: 2.3006134969325154
# Вероятность отказа: 0.6165644171779141
